# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.0.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\guvi project\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in e:\guvi project\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.0.1-cp312-cp312-win_amd64.whl (16.3 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.0.1 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("E:/Guvi Project/Customers.csv", encoding='ISO-8859-1')

# %%
df
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia    7/3/1939
# 1      Western Australia     6522      Australia      Australia   9/27/1979
# 2               Victoria     3380      Australia      Australia   5/26/1947
# 3        South Australia     5223      Australia      Australia   9/17/1957
# 4               Victoria     3698      Australia      Australia  11/19/1965
# ...                  ...      ...            ...            ...         ...
# 15261              Texas    77017  United States  North America   3/25/1936
# 15262           Virginia    22101  United States  North America   2/16/1992
# 15263     North Carolina    28405  United States  North America   11/9/1937
# 15264         California    92501  United States  North America  10/12/1937
# 15265           Michigan    48302  United States  North America   8/18/1965
#
# [15266 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
df["State Code"].fillna('Unknown', inplace=True)
# Out:
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7228\813081064.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["State Code"].fillna('Unknown', inplace=True)

# %%
df
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia    7/3/1939
# 1      Western Australia     6522      Australia      Australia   9/27/1979
# 2               Victoria     3380      Australia      Australia   5/26/1947
# 3        South Australia     5223      Australia      Australia   9/17/1957
# 4               Victoria     3698      Australia      Australia  11/19/1965
# ...                  ...      ...            ...            ...         ...
# 15261              Texas    77017  United States  North America   3/25/1936
# 15262           Virginia    22101  United States  North America   2/16/1992
# 15263     North Carolina    28405  United States  North America   11/9/1937
# 15264         California    92501  United States  North America  10/12/1937
# 15265           Michigan    48302  United States  North America   8/18/1965
#
# [15266 rows x 10 columns]

# %%
df['Birthday'] = pd.to_datetime(df['Birthday'])

# %%
df
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent   Birthday
# 0        South Australia     5523      Australia      Australia 1939-07-03
# 1      Western Australia     6522      Australia      Australia 1979-09-27
# 2               Victoria     3380      Australia      Australia 1947-05-26
# 3        South Australia     5223      Australia      Australia 1957-09-17
# 4               Victoria     3698      Australia      Australia 1965-11-19
# ...                  ...      ...            ...            ...        ...
# 15261              Texas    77017  United States  North America 1936-03-25
# 15262           Virginia    22101  United States  North America 1992-02-16
# 15263     North Carolina    28405  United States  North America 1937-11-09
# 15264         California    92501  United States  North America 1937-10-12
# 15265           Michigan    48302  United States  North America 1965-08-18
#
# [15266 rows x 10 columns]

# %%
column_types = df.dtypes
print(column_types)
# Out:
# CustomerKey     int64
# Gender         object
# Name           object
# City           object
# State Code     object
# State          object
# Zip Code       object
# Country        object
# Continent      object
# Birthday       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
df.dtypes
# Out:
# CustomerKey             int64
# Gender                 object
# Name                   object
# City                   object
# State Code             object
# State                  object
# Zip Code               object
# Country                object
# Continent              object
# Birthday       datetime64[ns]
# dtype: object

# %%
df.to_csv("Customer.csv",index=False)

# %%
df1=pd.read_csv("E:\Guvi Project\Data_Dictionary.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7228\1896563801.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df1=pd.read_csv("E:\Guvi Project\Data_Dictionary.csv")

# %%
df1
# Out:
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# 18       Customers        Birthday
# 19        Products      ProductKey
# 20        Products    Product Name
# 21        Products           Brand
# 22        Products           Color
# 23        Products   Unit Cost USD
# 24        Products  Unit Price USD
# 25        Products  SubcategoryKey
# 26        Products     Subcategory
# 27        Products     CategoryKey
# 28        Products        Category
# 29          Stores        StoreKey
# 30          Stores         Country
# 31          Stores           State
# 32          Stores   Square Meters
# 33          Stores       Open Date
# 34  Exchange Rates            Date
# 35  Exchange Rates        Currency
# 36  Exchange Rates        Exchange
#
#                                           Description
# 0                            Unique ID for each order
# 1   Identifies individual products purchased as pa...
# 2                           Date the order was placed
# 3                        Date the order was delivered
# 4   Unique key identifying which customer placed t...
# 5   Unique key identifying which store processed t...
# 6   Unique key identifying which product was purch...
# 7                           Number of items purchased
# 8                  Currency used to process the order
# 9                   Primary key to identify customers
# 10                                    Customer gender
# 11                                 Customer full name
# 12                                      Customer city
# 13                       Customer state (abbreviated)
# 14                              Customer state (full)
# 15                                  Customer zip code
# 16                                   Customer country
# 17                                 Customer continent
# 18                             Customer date of birth
# 19                   Primary key to identify products
# 20                                       Product name
# 21                                      Product brand
# 22                                      Product color
# 23                 Cost to produce the product in USD
# 24                          Product list price in USD
# 25              Key to identify product subcategories
# 26                           Product subcategory name
# 27                 Key to identify product categories
# 28                              Product category name
# 29                     Primary key to identify stores
# 30                                      Store country
# 31                                        Store state
# 32                   Store footprint in square meters
# 33                                    Store open date
# 34                                               Date
# 35                                      Currency code
# 36                      Exchange rate compared to USD

# %%
df1.isnull().sum()
# Out:
# Table          0
# Field          0
# Description    0
# dtype: int64

# %%
df1.to_csv("Formated_Files/Data_Dictionary.csv",index=False)

# %%
df2=pd.read_csv("E:\Guvi Project\Exchange_Rates.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7228\2760723911.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df2=pd.read_csv("E:\Guvi Project\Exchange_Rates.csv")

# %%
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
df2
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df2.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
df2.to_csv("Formated_Files/Exchange_Rates.csv",index=False)

# %%
df3=pd.read_csv("E:\Guvi Project\Products.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7228\2284649680.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df3=pd.read_csv("E:\Guvi Project\Products.csv")

# %%
df3.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
df3.to_csv("Formated_Files/Products.csv",index=False)

# %%
df4=pd.read_csv("E:\Guvi Project\Sales.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7228\3419584635.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df4=pd.read_csv("E:\Guvi Project\Sales.csv")

# %%
df4[df4['Delivery Date'].isnull()]
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 6            366004          1   1/1/2016           NaN      1107461
# 7            366004          2   1/1/2016           NaN      1107461
# 8            366005          1   1/1/2016           NaN       844003
# 9            366007          1   1/1/2016           NaN      2035771
# ...             ...        ...        ...           ...          ...
# 62867       2243025          1  2/20/2021           NaN      1909290
# 62868       2243025          2  2/20/2021           NaN      1909290
# 62869       2243026          1  2/20/2021           NaN      1737466
# 62872       2243028          1  2/20/2021           NaN      1728060
# 62879       2243030          1  2/20/2021           NaN      1216913
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# 6            38         163         6           GBP
# 7            38        1529         2           GBP
# 8            33         421         4           EUR
# 9            43        1617         1           USD
# ...         ...         ...       ...           ...
# 62867        49        1128         2           USD
# 62868        49        2511         2           USD
# 62869        49          58         6           USD
# 62872        66        1584         3           USD
# 62879        43         632         3           USD
#
# [49719 rows x 9 columns]

# %%
df_backup = df.copy()  # Create a backup
df4.drop('Delivery Date', axis=1, inplace=True)  # Drop the column from the original 
#we are dropping delivery date it don't not affect dataset because most of data has been lost

# %%
df4
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1   1/1/2016       265598        10        1304
# 1            366001          1   1/1/2016      1269051         0        1048
# 2            366001          2   1/1/2016      1269051         0        2007
# 3            366002          1   1/1/2016       266019         0        1106
# 4            366002          2   1/1/2016       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1  2/20/2021      1216913        43         632
# 62880       2243031          1  2/20/2021       511229         0          98
# 62881       2243032          1  2/20/2021       331277         0        1613
# 62882       2243032          2  2/20/2021       331277         0        1717
# 62883       2243032          3  2/20/2021       331277         0         464
#
#        Quantity Currency Code
# 0             1           CAD
# 1             2           USD
# 2             1           USD
# 3             7           CAD
# 4             1           CAD
# ...         ...           ...
# 62879         3           USD
# 62880         4           EUR
# 62881         2           CAD
# 62882         2           CAD
# 62883         7           CAD
#
# [62884 rows x 8 columns]

# %%
df4['Order Date'] = pd.to_datetime(df4['Order Date'])

# %%
df4
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
#        Quantity Currency Code
# 0             1           CAD
# 1             2           USD
# 2             1           USD
# 3             7           CAD
# 4             1           CAD
# ...         ...           ...
# 62879         3           USD
# 62880         4           EUR
# 62881         2           CAD
# 62882         2           CAD
# 62883         7           CAD
#
# [62884 rows x 8 columns]

# %%
df4.to_csv("Formated_Files/Sale.csv",index=False)

# %%
df5=pd.read_csv("E:\Guvi Project\Stores.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7228\3227996691.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df5=pd.read_csv("E:\Guvi Project\Stores.csv")

# %%
df5
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# 4   12/9/2015
# ..        ...
# 62   3/6/2008
# 63   1/1/2010
# 64   1/1/2012
# 65   1/1/2014
# 66   1/1/2010
#
# [67 rows x 5 columns]

# %%
df5.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
df5["Square Meters"].fillna('Unknown', inplace=True)
# Out:
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7228\2296537504.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df5["Square Meters"].fillna('Unknown', inplace=True)
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7228\2296537504.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df5["Square Meters"].fillna('Unknown', inplace=True)

# %%
df5.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
df5
# Out:
#     StoreKey        Country                         State Square Meters  \
# 0          1      Australia  Australian Capital Territory         595.0
# 1          2      Australia            Northern Territory         665.0
# 2          3      Australia               South Australia        2000.0
# 3          4      Australia                      Tasmania        2000.0
# 4          5      Australia                      Victoria        2000.0
# ..       ...            ...                           ...           ...
# 62        63  United States                          Utah        2000.0
# 63        64  United States                 Washington DC        1330.0
# 64        65  United States                 West Virginia        1785.0
# 65        66  United States                       Wyoming         840.0
# 66         0         Online                        Online       Unknown
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# 4   12/9/2015
# ..        ...
# 62   3/6/2008
# 63   1/1/2010
# 64   1/1/2012
# 65   1/1/2014
# 66   1/1/2010
#
# [67 rows x 5 columns]

# %%
df5['Open Date'] = pd.to_datetime(df5['Open Date'])

# %%
df5
# Out:
#     StoreKey        Country                         State Square Meters  \
# 0          1      Australia  Australian Capital Territory         595.0
# 1          2      Australia            Northern Territory         665.0
# 2          3      Australia               South Australia        2000.0
# 3          4      Australia                      Tasmania        2000.0
# 4          5      Australia                      Victoria        2000.0
# ..       ...            ...                           ...           ...
# 62        63  United States                          Utah        2000.0
# 63        64  United States                 Washington DC        1330.0
# 64        65  United States                 West Virginia        1785.0
# 65        66  United States                       Wyoming         840.0
# 66         0         Online                        Online       Unknown
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# 4  2015-12-09
# ..        ...
# 62 2008-03-06
# 63 2010-01-01
# 64 2012-01-01
# 65 2014-01-01
# 66 2010-01-01
#
# [67 rows x 5 columns]

# %%
df5.to_csv("Formated_Files/Store.csv",index=False)

# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Using cached mysql_connector_python-9.0.0-cp312-cp312-win_amd64.whl.metadata (2.0 kB)
# Using cached mysql_connector_python-9.0.0-cp312-cp312-win_amd64.whl (14.3 MB)
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
conn=mysql.connector.connect(user='root', password='password',
                              host='127.0.0.1',
                              database='Data_spark')
my_cursor = conn.cursor()

# %%
df=pd.read_csv("E:\Guvi Project\Formated_Files\Customer.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7672\4055364019.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df=pd.read_csv("E:\Guvi Project\Formated_Files\Customer.csv")

# %%
create_table_sql = '''CREATE TABLE IF NOT EXISTS Customer (
    CustomerKey INT NOT NULL,
    Gender VARCHAR(255) NOT NULL,
    Name VARCHAR(255) NOT NULL,
    City VARCHAR(255) NOT NULL,
    StateCode VARCHAR(255) NULL, 
    State VARCHAR(255) NULL,
    ZipCode VARCHAR(255) NOT NULL, 
    Country VARCHAR(255) NOT NULL,
    Continent VARCHAR(255) NOT NULL,
    Birthday DATE 
)'''

                 

# Execute table creation
my_cursor.execute(create_table_sql)

# %%
insert_sql = """INSERT INTO Customer(
                  CustomerKey,
                  Gender,
                  Name,
                  City,
                  StateCode,
                  State,
                  ZipCode,
                  Country,
                  Continent,
                  Birthday)
                VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""


# Convert DataFrame to list of tuples
data = df.values.tolist()

# Execute batch insert
my_cursor.executemany(insert_sql, data)

# Commit the transaction using the connection object
conn.commit()

# Print number of rows inserted
print(my_cursor.rowcount, "rows were inserted.")

# Close the cursor and connection
my_cursor.close()
conn.close()
# Out:
# 15266 rows were inserted.

# %%
df1=pd.read_csv("E:\Guvi Project\Formated_Files\Data_Dictionary.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7672\829680491.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df1=pd.read_csv("E:\Guvi Project\Formated_Files\Data_Dictionary.csv")

# %%
df1.dtypes
# Out:
# Table          object
# Field          object
# Description    object
# dtype: object

# %%
create_table_sql = '''CREATE TABLE IF NOT EXISTS Data_dictionary (
    `Table` VARCHAR(255) NOT NULL,
    Field VARCHAR(255) NOT NULL,
    Description VARCHAR(255) NOT NULL
)'''

# Execute table creation
my_cursor.execute(create_table_sql)

# %%
insert_sql = """INSERT INTO Data_dictionary(
                  `Table`,
                  Field,
                  Description
                )
                VALUES(%s, %s, %s)"""



# Convert DataFrame to list of tuples
data = df1.values.tolist()

# Execute batch insert
my_cursor.executemany(insert_sql, data)

# Commit the transaction using the connection object
conn.commit()

# Print number of rows inserted
print(my_cursor.rowcount, "rows were inserted.")

# Close the cursor and connection
my_cursor.close()
conn.close()
# Out:
# 37 rows were inserted.

# %%
df2=pd.read_csv("E:\Guvi Project\Formated_Files\Exchange_Rates.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7672\4277810517.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df2=pd.read_csv("E:\Guvi Project\Formated_Files\Exchange_Rates.csv")

# %%
df2
# Out:
#              Date Currency  Exchange
# 0      2015-01-01      USD    1.0000
# 1      2015-01-01      CAD    1.1583
# 2      2015-01-01      AUD    1.2214
# 3      2015-01-01      EUR    0.8237
# 4      2015-01-01      GBP    0.6415
# ...           ...      ...       ...
# 11210  2021-02-20      USD    1.0000
# 11211  2021-02-20      CAD    1.2610
# 11212  2021-02-20      AUD    1.2723
# 11213  2021-02-20      EUR    0.8238
# 11214  2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df2.dtypes
# Out:
# Date         object
# Currency     object
# Exchange    float64
# dtype: object

# %%
conn=mysql.connector.connect(user='root', password='password',
                              host='127.0.0.1',
                              database='Data_spark')
my_cursor = conn.cursor()

create_table_sql = '''CREATE TABLE IF NOT EXISTS Exchange_Rates (
    Date   VARCHAR(255) NOT NULL,
    Currency VARCHAR(255) NOT NULL,
    Exchange VARCHAR(255) NOT NULL
)'''

# Execute table creation
my_cursor.execute(create_table_sql)

# %%
insert_sql = """INSERT INTO Exchange_Rates(
                  Date,
                  Currency,
                  Exchange
                  )
                VALUES(%s, %s, %s)"""


# Convert DataFrame to list of tuples
data = df2.values.tolist()

# Execute batch insert
my_cursor.executemany(insert_sql, data)

# Commit the transaction using the connection object
conn.commit()

# Print number of rows inserted
print(my_cursor.rowcount, "rows were inserted.")

# Close the cursor and connection
my_cursor.close()
conn.close()
# Out:
# 11215 rows were inserted.

# %%
df3=pd.read_csv("E:\Guvi Project\Formated_Files\Products.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7672\31200608.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df3=pd.read_csv("E:\Guvi Project\Formated_Files\Products.csv")

# %%
df3.dtypes
# Out:
# ProductKey         int64
# Product Name      object
# Brand             object
# Color             object
# Unit Cost USD     object
# Unit Price USD    object
# SubcategoryKey     int64
# Subcategory       object
# CategoryKey        int64
# Category          object
# dtype: object

# %%
conn=mysql.connector.connect(user='root', password='password',
                              host='127.0.0.1',
                              database='Data_spark')
my_cursor = conn.cursor()


create_table_sql = '''CREATE TABLE IF NOT EXISTS Products (
    ProductKey INT NOT NULL,
    ProductName VARCHAR(255) NOT NULL,
    Brand VARCHAR(255) NOT NULL,
    Color VARCHAR(255) NOT NULL,
    UnitCostUSD VARCHAR(255) NULL, 
    UnitPriceUSD VARCHAR(255) NULL,
    SubcategoryKey INT NOT NULL, 
    Subcategory VARCHAR(255) NOT NULL,
    CategoryKey INT NOT NULL,
    Category VARCHAR(255) NOT NULL
    
)'''
          

# Execute table creation
my_cursor.execute(create_table_sql)

# %%
insert_sql = """INSERT INTO Products(
                  ProductKey,
                  ProductName,
                  Brand,
                  Color,
                  UnitCostUSD,
                  UnitPriceUSD,
                  SubcategoryKey,
                  Subcategory,
                  CategoryKey,
                  Category
                  )
                VALUES(%s,%s, %s, %s,%s, %s, %s,%s, %s, %s)"""


# Convert DataFrame to list of tuples
data = df3.values.tolist()

# Execute batch insert
my_cursor.executemany(insert_sql, data)

# Commit the transaction using the connection object
conn.commit()

# Print number of rows inserted
print(my_cursor.rowcount, "rows were inserted.")

# Close the cursor and connection
my_cursor.close()
conn.close()
# Out:
# 2517 rows were inserted.

# %%
df4=pd.read_csv("E:\Guvi Project\Formated_Files\Sale.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7672\3567855446.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df4=pd.read_csv("E:\Guvi Project\Formated_Files\Sale.csv")

# %%
df4.dtypes
# Out:
# Order Number      int64
# Line Item         int64
# Order Date       object
# CustomerKey       int64
# StoreKey          int64
# ProductKey        int64
# Quantity          int64
# Currency Code    object
# dtype: object

# %%
conn=mysql.connector.connect(user='root', password='password',
                              host='127.0.0.1',
                              database='Data_spark')
my_cursor = conn.cursor()


create_table_sql = '''CREATE TABLE IF NOT EXISTS Sales (
    OrderNumber INT NOT NULL,
    LineItem INT NOT NULL,
    OrderDate VARCHAR(255) NOT NULL,
    CustomerKey INT NOT NULL,
    StoreKey INT NOT NULL, 
    ProductKey INT NOT NULL,
    Quantity INT NOT NULL, 
    CurrencyCode VARCHAR(255) NOT NULL
   
)'''     

# Execute table creation
my_cursor.execute(create_table_sql)

# %%
insert_sql = """INSERT INTO Sales (
                  OrderNumber,
                  LineItem,
                  OrderDate,
                  CustomerKey,
                  StoreKey,
                  ProductKey,
                  Quantity,
                  CurrencyCode
                )
                VALUES(%s, %s, %s, %s, %s, %s, %s, %s)"""



# Convert DataFrame to list of tuples
data = df4.values.tolist()

# Execute batch insert
my_cursor.executemany(insert_sql, data)

# Commit the transaction using the connection object
conn.commit()

# Print number of rows inserted
print(my_cursor.rowcount, "rows were inserted.")

# Close the cursor and connection
my_cursor.close()
conn.close()
# Out:
# 62884 rows were inserted.

# %%
df5=pd.read_csv("E:\Guvi Project\Formated_Files\Store.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Jacquline\AppData\Local\Temp\ipykernel_7672\2926009199.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df5=pd.read_csv("E:\Guvi Project\Formated_Files\Store.csv")

# %%
df5.dtypes
# Out:
# StoreKey          int64
# Country          object
# State            object
# Square Meters    object
# Open Date        object
# dtype: object

# %%
conn=mysql.connector.connect(user='root', password='password',
                              host='127.0.0.1',
                              database='Data_spark')
my_cursor = conn.cursor()


create_table_sql = '''CREATE TABLE IF NOT EXISTS Store (
    StoreKey   INT NOT NULL,
    Country    VARCHAR(255) NOT NULL,
    State VARCHAR(255) NOT NULL,
    SquareMeters VARCHAR(255) NOT NULL, 
    OpenDate VARCHAR(255) NOT NULL
    
   
)'''     

# Execute table creation
my_cursor.execute(create_table_sql)

# %%
insert_sql = """INSERT INTO Store (
                  StoreKey,
                  Country,
                  State,
                  SquareMeters,
                  OpenDate
                )
                VALUES(%s, %s, %s, %s, %s)"""




# Convert DataFrame to list of tuples
data = df5.values.tolist()

# Execute batch insert
my_cursor.executemany(insert_sql, data)

# Commit the transaction using the connection object
conn.commit()

# Print number of rows inserted
print(my_cursor.rowcount, "rows were inserted.")

# Close the cursor and connection
my_cursor.close()
conn.close()
# Out:
# 67 rows were inserted.
